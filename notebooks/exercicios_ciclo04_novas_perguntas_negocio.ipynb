# %% [markdown]
# <a href="https://colab.research.google.com/github/cglima/ftc_dados_python/blob/main/exercicios_ciclo04_novas_perguntas_negocio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios Ciclo 04 - Novas perguntas de negócios

# %%
from google import colab as cl
import pandas as pd
import re

# %%
file_upload = cl.files.upload()
# Out:
#      <input type="file" id="files-e92224d4-c287-43b8-a2a2-a990ce75b2aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e92224d4-c287-43b8-a2a2-a990ce75b2aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('train.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# qual o tipo de variável em cada coluna
# object == texto = string

df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %% [markdown]
# ## Limpeza dos dados

# %%
df1 = df.copy()
# excluir as linhas com os registros vazios (NaN)
# idade dos entregadores vazia
linhas_selecionadas = df1['Delivery_person_Age'] != 'NaN '
df1 = df1.loc[linhas_selecionadas, :].copy()

# ID vazio
linhas_selecionadas = df1['ID'] != 'NaN '
df1 = df1.loc[linhas_selecionadas, :].copy()

# City vazia
linhas_selecionadas = df1['City'] != 'NaN '
df1 = df1.loc[linhas_selecionadas, :].copy()

# Road_traffic_density vazia
linhas_selecionadas = df1['Road_traffic_density'] != 'NaN '
df1 = df1.loc[linhas_selecionadas, :].copy()

# 1. convertendo a coluna Age de texto para numero
df1['Delivery_person_Age'] = df1['Delivery_person_Age'].astype(int)

# 2. convertendo a coluna Rating de texto para numero decimal (float)
df1['Delivery_person_Ratings'] = df1['Delivery_person_Ratings'].astype(float)

# 3. convertendo a coluna order_date de texto para data
df1['Order_Date'] = pd.to_datetime(df1['Order_Date'], format='%d-%m-%Y')

# 4. convertendo multiple_deliveries de texto para numero inteiro (int)
linhas_selecionadas = df1['multiple_deliveries'] != 'NaN '
df1 = df1.loc[linhas_selecionadas, :].copy()
df1['multiple_deliveries'] = df1['multiple_deliveries'].astype(int)

# 5. removendo os espaços dentro de strings/texto/object
# df1.iloc[0, 1]
df1.loc[0, 'City']

df1.loc[:, 'ID'] = df1.loc[:, 'ID'].str.strip()
df1.loc[:, 'Delivery_person_ID'] = df1.loc[:, 'Delivery_person_ID'].str.strip()
df1.loc[:, 'Road_traffic_density'] = df1.loc[:, 'Road_traffic_density'].str.strip()
df1.loc[:, 'Type_of_order'] = df1.loc[:, 'Type_of_order'].str.strip()
df1.loc[:, 'Type_of_vehicle'] = df1.loc[:, 'Type_of_vehicle'].str.strip()
df1.loc[:, 'City'] = df1.loc[:, 'City'].str.strip()
df1.loc[:, 'Festival'] = df1.loc[:, 'Festival'].str.strip()

# 6. removendo o texto de números
df1['Time_taken(min)'] = df1['Time_taken(min)'].apply(lambda x: re.findall( r'\d+', x))

# 7. resetando o index do dataset
df1 = df1.reset_index(drop=True)

# %%
df1.dtypes
# Out:
# ID                                     object
# Delivery_person_ID                     object
# Delivery_person_Age                     int64
# Delivery_person_Ratings               float64
# Restaurant_latitude                   float64
# Restaurant_longitude                  float64
# Delivery_location_latitude            float64
# Delivery_location_longitude           float64
# Order_Date                     datetime64[ns]
# Time_Orderd                            object
# Time_Order_picked                      object
# Weatherconditions                      object
# Road_traffic_density                   object
# Vehicle_condition                       int64
# Type_of_order                          object
# Type_of_vehicle                        object
# multiple_deliveries                     int64
# Festival                               object
# City                                   object
# Time_taken(min)                        object
# dtype: object

# %%
df1.head(30)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x4607     INDORES13DEL02                   37                      4.9
# 1   0xb379     BANGRES18DEL02                   34                      4.5
# 2   0x5d6d     BANGRES19DEL01                   23                      4.4
# 3   0x7a6a    COIMBRES13DEL02                   38                      4.7
# 4   0x70a2     CHENRES12DEL01                   32                      4.6
# 5   0x9bb4      HYDRES09DEL03                   22                      4.8
# 6   0x95b4   RANCHIRES15DEL01                   33                      4.7
# 7   0x9eb2      MYSRES15DEL02                   35                      4.6
# 8   0x1102      HYDRES05DEL02                   22                      4.8
# 9   0xcdcd      DEHRES17DEL01                   36                      4.2
# 10  0xd987      KOCRES16DEL01                   21                      4.7
# ...

# %% [markdown]
# ## Novas perguntas de Negócio

# %% [markdown]
# 1. Qual o número total de entregas cadastradas na base de dados?

# %%
# contar todas as linhas da coluna delivery_person_ID
df1['Delivery_person_ID'].count()
# Out:
# 41611

# %% [markdown]
# 2. Qual o número total de entregadores únicos cadastrados na base de dados?

# %%
# contar todos os Delivery_person_ID unicos
len(df1['Delivery_person_ID'].unique())
# Out:
# 1320

# %% [markdown]
# 3. Qual a média de idade dos entregadores por cidade?

# %%
# selecionar a coluna com a idade dos entregadores
idades_e_cidades = df1.loc[:, ['Delivery_person_Age', 'City']]
#agrupar por cidade
grupo_cidade = idades_e_cidades.groupby(['City'])
#calcular a media das idades para cada cidade
media_idades_por_cidade = grupo_cidade['Delivery_person_Age'].mean()

print(media_idades_por_cidade)
# Out:
# City
# Metropolitian    29.781869
# Semi-Urban       32.565789
# Urban            28.893489
# Name: Delivery_person_Age, dtype: float64

# %% [markdown]
# 4. Qual a mediana de idade dos entregadores por cidade?

# %%
idades_e_cidades = df1.loc[:, ['Delivery_person_Age', 'City']]
grupo_cidade = idades_e_cidades.groupby(['City'])
mediana_idades_por_cidade = grupo_cidade['Delivery_person_Age'].median()

print(mediana_idades_por_cidade)
# Out:
# City
# Metropolitian    30.0
# Semi-Urban       32.0
# Urban            28.0
# Name: Delivery_person_Age, dtype: float64

# %% [markdown]
# 5. Qual a média das avaliações das entregas feitas por densidade de tráfego?

# %%
# selecionar as colunas Delivery_person_Ratings e Road_traffic_density
entregas_e_densidade_trafego = df1.loc[:, ['Delivery_person_Ratings', 'Road_traffic_density']]
#agrupar por Road_traffic_density
grupo_densidade_trafego = entregas_e_densidade_trafego.groupby(['Road_traffic_density'])
# calcular a media das entregar por densidade de tráfego
media_entregas_trafego = grupo_densidade_trafego['Delivery_person_Ratings'].mean()

print(media_entregas_trafego)
# Out:
# Road_traffic_density
# High      4.652538
# Jam       4.594428
# Low       4.645947
# Medium    4.660335
# Name: Delivery_person_Ratings, dtype: float64

# %% [markdown]
# 6. Qual a quantidade de entregas feitas por cidade?

# %%
# selecionar o total de entregas e cidades
#agrupar por cidade
# contar todas as entregas
entregas_por_cidade = df1.loc[:, ['ID', 'City']].groupby('City').count()
print(entregas_por_cidade)
# Out:
#                   ID
# City
# Metropolitian  31967
# Semi-Urban       152
# Urban           9492

# %% [markdown]
# 7. Qual a média, mediana e desvio padrão das entregas feitas por cidade e por tipo de veículo?

# %%
# selecionar as entregas
columns = ['ID', 'City', 'Type_of_vehicle' ]
# agrupar por cidade e por tipo de veículo
entregas = df1.loc[:, columns].groupby(['City', 'Type_of_vehicle']).count()

entregas
# Out:
#                                    ID
# City          Type_of_vehicle
# Metropolitian electric_scooter   2570
#               motorcycle        18984
#               scooter           10413
# Semi-Urban    electric_scooter      3
#               motorcycle          140
#               scooter               9
# Urban         electric_scooter    792
#               motorcycle         5297
#               scooter            3403

# %% [markdown]
#  8. Qual a primeira data de entrega por cada cidade?

# %%
cols = ['Order_Date', 'City']
primeira_data = df1.loc[:, cols].groupby(['City']).max()
primeira_data
# Out:
#               Order_Date
# City
# Metropolitian 2022-04-06
# Semi-Urban    2022-04-06
# Urban         2022-04-06

# %% [markdown]
#  9. Qual a última data de entrega por cada cidade?

# %%
cols = ['Order_Date', 'City']
primeira_data = df1.loc[:, cols].groupby(['City']).min()
primeira_data
# Out:
#               Order_Date
# City
# Metropolitian 2022-02-11
# Semi-Urban    2022-02-11
# Urban         2022-02-11

# %% [markdown]
#  10. Qual a média de avaliações das entregas feitas por condições climáticas?

# %%
cols = ['Delivery_person_Ratings', 'Weatherconditions']
media_avaliacoes = df1.loc[:, cols].groupby('Weatherconditions').mean()
media_avaliacoes
# Out:
#                        Delivery_person_Ratings
# Weatherconditions
# conditions Cloudy                     4.651945
# conditions Fog                        4.653087
# conditions Sandstorms                 4.612144
# conditions Stormy                     4.612569
# conditions Sunny                      4.656164
# conditions Windy                      4.616844

# %% [markdown]
#  11. Qual o valor da avaliação mais baixa feita por tipo de condição climática e
# por densidade de tráfego?

# %%
cols = ['Delivery_person_Ratings', 'Weatherconditions', 'Road_traffic_density']
menor_avaliacao = df.loc[:, cols].groupby(['Weatherconditions', 'Road_traffic_density'])['Delivery_person_Ratings'].min()
menor_avaliacao
# Out:
# Weatherconditions      Road_traffic_density
# conditions Cloudy      High                       4
#                        Jam                        4
#                        Low                      3.5
#                        Medium                     4
# conditions Fog         High                       4
#                        Jam                        4
#                        Low                      3.5
#                        Medium                     4
# conditions NaN         High                    NaN
#                        Jam                     NaN
#                        Low                     NaN
#                        Medium                  NaN
#                        NaN                        1
# conditions Sandstorms  High                       4
#                        Jam                      3.5
#                        Low                        4
#                        Medium                   3.5
# ...

# %% [markdown]
#  12. Qual a média, mediana e desvio padrão das avaliações por cada tipo de condições de veículos?

# %%
cols = ['Delivery_person_Ratings', 'Vehicle_condition']
avaliacoes_veiculos = df1.loc[:, cols].groupby(['Vehicle_condition'])

media_condicao_veiculos = avaliacoes_veiculos.mean()
mediana_condicao_veiculos = avaliacoes_veiculos.median()
desvio_condicao_veiculos = avaliacoes_veiculos.std()

print(media_condicao_veiculos)
print(mediana_condicao_veiculos)
print(desvio_condicao_veiculos)
# Out:
#                    Delivery_person_Ratings
# Vehicle_condition
# 0                                 4.610083
# 1                                 4.646771
# 2                                 4.644677
#                    Delivery_person_Ratings
# Vehicle_condition
# 0                                      4.7
# 1                                      4.7
# 2                                      4.7
#                    Delivery_person_Ratings
# Vehicle_condition
# 0                                 0.297498
# 1                                 0.321973
# 2                                 0.324855

# %% [markdown]
#  13. Quantas entregas foram feitas no Festival?

# %%
df_festival = df1.loc[df1['Festival'] == 'Yes']

print(f'{df_festival.shape[0]} entregas foram feitas no Festival')
# Out:
# 833 entregas foram feitas no Festival

# %% [markdown]
#  14. Qual a avaliação média das entregas feitas no Festival?

# %%
cols = ['Delivery_person_Ratings', 'Festival']
filtro = df1.loc[:, 'Festival'] == 'Yes'

media_avaliacoes_festival = df_festival.loc[:, cols].groupby('Festival').mean()
media_avaliacoes_festival
# Out:
#           Delivery_person_Ratings
# Festival
# Yes                      4.495918

# %% [markdown]
#  15. Qual a menor avaliação feita em uma entrega no Festival e por cidade?

# %%
cols = ['Delivery_person_Ratings', 'Festival', 'City']

df_festival.loc[:, cols].groupby(['Festival', 'City']).min()
# Out:
#                         Delivery_person_Ratings
# Festival City
# Yes      Metropolitian                      2.5
#          Semi-Urban                         3.5
#          Urban                              2.5

# %% [markdown]
#  16. Qual a maior avaliação feita por tipo de pedido?

# %%
cols = ['Delivery_person_Ratings', 'Type_of_order']
maior_avaliacao_pedido = df1.loc[:, cols].groupby(['Type_of_order']).max()
maior_avaliacao_pedido
# Out:
#                Delivery_person_Ratings
# Type_of_order
# Buffet                             5.0
# Drinks                             5.0
# Meal                               5.0
# Snack                              5.0

# %% [markdown]
#  17. Qual a idade do entregador mais velho da planilha de dados?

# %%
df1['Delivery_person_Age'].max()
# Out:
# 39

# %% [markdown]
#  18. Qual a idade do entregador mais novo da planilha de dados?

# %%
df1['Delivery_person_Age'].min()
# Out:
# 20

# %% [markdown]
#  19. Quantas entregas foram feitas em cada condição climática?

# %%
cols = ['ID', 'Weatherconditions']

entregas_codicoes_climaticas = df.loc[:, cols].groupby(['Weatherconditions']).count()
entregas_codicoes_climaticas
# Out:
#                          ID
# Weatherconditions
# conditions Cloudy      7536
# conditions Fog         7654
# conditions NaN          616
# conditions Sandstorms  7495
# conditions Stormy      7586
# conditions Sunny       7284
# conditions Windy       7422

# %% [markdown]
#  20. Quantas entregas foram feitas em cada tipo de densidade de trânsito?

# %%
cols = ['ID', 'Road_traffic_density']

entregas_densidade_transito = df1.loc[:, cols].groupby(['Road_traffic_density']).count()

entregas_densidade_transito
# Out:
#                          ID
# Road_traffic_density
# High                   4119
# Jam                   13207
# Low                   14112
# Medium                10173
